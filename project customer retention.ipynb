# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the dataset
df = pd.read_excel(r"C:\Users\LENOVO\Desktop\copy of customer_retention_dataset.xlsx")

# %%
# print the dataset
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
# lets check the shape of dataset 
df.shape
# Out:
# (269, 71)

# %% [markdown]
# As we see we have 269 rows and 71 columns in dataset

# %%
# print all column
pd.set_option('max_columns', None)
df.head(2)
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# 1                              Above 4 years
#
#   6 How many times you have made an online purchase in the past 1 year?  \
# 0                                        31-40 times
# 1                                 41 times and above
#
#   7 How do you access the internet while shopping on-line?  \
# 0                                            Dial-up
# 1                                              Wi-Fi
#
# ...

# %% [markdown]
# ## EDA

# %%
# Check all the column names
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
# checking the null values in the dataframe
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
# let's check the null values again
sns.heatmap(df.isnull(),cmap="cool_r")
plt.show()

# %% [markdown]
# from above we can see no NAN present in our dataset

# %%
# to get the good overview of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
# check the type of dataset
df.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %% [markdown]
# from this we can see i column is int type and remaining 70 are object type

# %%
# Checking number of unique values in each column
df.nunique().to_frame("No of Unique Values")
# Out:
#                                                     No of Unique Values
# 1Gender of respondent                                                 2
# 2 How old are you?                                                    5
# 3 Which city do you shop online from?                                11
# 4 What is the Pin Code of where you shop online...                   39
# 5 Since How Long You are Shopping Online ?                            5
# ...                                                                 ...
# Longer delivery period                                                6
# Change in website/Application design                                  7
# Frequent disruption when moving from one page t...                    8
# Website is as efficient as before                                     8
# Which of the Indian online retailer would you r...                    8
#
# [71 rows x 1 columns]

# %%
# checking the value counts of each columns
for i in df.columns:
    print(df[i].value_counts())
    print('**********************************************************')
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64
# **********************************************************
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64
# **********************************************************
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64
# **********************************************************
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 173229     9
# 173212     9
# 250001     9
# 122018     8
# 560037     8
# 132036     8
# 560010     8
# 110011     7
# 110008     7
# 201306     7
# 110014     6
# 110018     6
# 201008     5
# ...

# %% [markdown]
# ### DATA VISUALIZATION

# %%
df['1Gender of respondent'].value_counts().plot(kind='bar')
df['1Gender of respondent'].value_counts()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %% [markdown]
# As we see no of female is high as compare to male

# %%
df['3 Which city do you shop online from?'].value_counts().plot(kind='bar')
df['3 Which city do you shop online from?'].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Ghaziabad        18
# Solan            18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %% [markdown]
# As we see From Delhi city there are more people who did online shopping

# %%
df['7 How do you access the internet while shopping on-line?'].value_counts().plot(kind='bar')
df['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %% [markdown]
# As we see while online shopping max people use mobile internet

# %%
df['8 Which device do you use to access the online shopping?'].value_counts().plot(kind='bar')
df['8 Which device do you use to access the online shopping?'].value_counts()
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %% [markdown]
# Max people do online shopping by smartphone

# %%
df['18 The content on the website must be easy to read and understand'].value_counts().plot(kind='bar')
df['18 The content on the website must be easy to read and understand'].value_counts()
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %%
df['19 Information on similar product to the one highlighted  is important for product comparison'].value_counts().plot(kind='bar')
df['19 Information on similar product to the one highlighted  is important for product comparison'].value_counts()
# Out:
# Strongly agree (5)    116
# Agree (4)              92
# Indifferent (3)        43
# Dis-agree (2)          18
# Name: 19 Information on similar product to the one highlighted  is important for product comparison, dtype: int64

# %%
df['20 Complete information on listed seller and product being offered is important for purchase decision.'].value_counts().plot(kind='bar')
df['20 Complete information on listed seller and product being offered is important for purchase decision.'].value_counts()
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: 20 Complete information on listed seller and product being offered is important for purchase decision., dtype: int64

# %%
df['21 All relevant information on listed products must be stated clearly'].value_counts().plot(kind='bar')
df['21 All relevant information on listed products must be stated clearly'].value_counts()
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: 21 All relevant information on listed products must be stated clearly, dtype: int64

# %%
df['22 Ease of navigation in website'].value_counts().plot(kind='bar')
df['22 Ease of navigation in website'].value_counts()
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: 22 Ease of navigation in website, dtype: int64

# %%
df['23 Loading and processing speed'].value_counts().plot(kind='bar')
df['23 Loading and processing speed'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Strongly disagree (1)     12
# Indifferent (3)           12
# Name: 23 Loading and processing speed, dtype: int64

# %%
df['24 User friendly Interface of the website'].value_counts().plot(kind='bar')
df['24 User friendly Interface of the website'].value_counts()
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: 24 User friendly Interface of the website, dtype: int64

# %%
df['25 Convenient Payment methods'].value_counts().plot(kind='bar')
df['25 Convenient Payment methods'].value_counts()
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: 25 Convenient Payment methods, dtype: int64

# %%
df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'].value_counts().plot(kind='bar')
df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'].value_counts()
# Out:
# Strongly agree (5)    141
# Agree (4)              86
# Disagree (2)           30
# indifferent  (3)       12
# Name: 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time, dtype: int64

# %%
df['27 Empathy (readiness to assist with queries) towards the customers'].value_counts().plot(kind='bar')
df['27 Empathy (readiness to assist with queries) towards the customers'].value_counts()
# Out:
# Strongly agree (5)       194
# Agree (4)                 42
# Strongly disagree (1)     18
# indifferent (3)           15
# Name: 27 Empathy (readiness to assist with queries) towards the customers, dtype: int64

# %%
df['28 Being able to guarantee the privacy of the customer'].value_counts().plot(kind='bar')
df['28 Being able to guarantee the privacy of the customer'].value_counts()
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: 28 Being able to guarantee the privacy of the customer, dtype: int64

# %%
df['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'].value_counts().plot(kind='bar')
df['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'].value_counts()
# Out:
# Strongly agree (5)       149
# Agree (4)                 94
# indifferent (3)           15
# Strongly disagree (1)     11
# Name: 29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.), dtype: int64

# %%
df['30 Online shopping gives monetary benefit and discounts'].value_counts().plot(kind='bar')
df['30 Online shopping gives monetary benefit and discounts'].value_counts()
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: 30 Online shopping gives monetary benefit and discounts, dtype: int64

# %%
df['31 Enjoyment is derived from shopping online'].value_counts().plot(kind='bar')
df['31 Enjoyment is derived from shopping online'].value_counts()
# Out:
# Strongly agree (5)       86
# indifferent (3)          75
# Agree (4)                59
# Strongly disagree (1)    30
# Dis-agree (2)            19
# Name: 31 Enjoyment is derived from shopping online, dtype: int64

# %%
df['32 Shopping online is convenient and flexible'].value_counts().plot(kind='bar')
df['32 Shopping online is convenient and flexible'].value_counts()
# Out:
# Strongly agree (5)    146
# Agree (4)              78
# indifferent (3)        33
# Dis-agree (2)          12
# Name: 32 Shopping online is convenient and flexible, dtype: int64

# %%
df['33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts().plot(kind='bar')
df['33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts()
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %%
df['34 Gaining access to loyalty programs is a benefit of shopping online'].value_counts().plot(kind='bar')
df['34 Gaining access to loyalty programs is a benefit of shopping online'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                 64
# indifferent (3)           64
# Dis-agree (2)             15
# Strongly disagree (1)     11
# Name: 34 Gaining access to loyalty programs is a benefit of shopping online, dtype: int64

# %%
df['35 Displaying quality Information on the website improves satisfaction of customers'].value_counts().plot(kind='bar')
df['35 Displaying quality Information on the website improves satisfaction of customers'].value_counts()
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: 35 Displaying quality Information on the website improves satisfaction of customers, dtype: int64

# %%
df['36 User derive satisfaction while shopping on a good quality website or application'].value_counts().plot(kind='bar')
df['36 User derive satisfaction while shopping on a good quality website or application'].value_counts()
# Out:
# Strongly agree (5)    175
# Agree (4)              86
# Dis-agree (2)           8
# Name: 36 User derive satisfaction while shopping on a good quality website or application, dtype: int64

# %%
df['37 Net Benefit derived from shopping online can lead to users satisfaction'].value_counts().plot(kind='bar')
df['37 Net Benefit derived from shopping online can lead to users satisfaction'].value_counts()
# Out:
# Strongly agree (5)    164
# Agree (4)              54
# indifferent (3)        40
# Dis-agree (2)          11
# Name: 37 Net Benefit derived from shopping online can lead to users satisfaction, dtype: int64

# %%
df['38 User satisfaction cannot exist without trust'].value_counts().plot(kind='bar')
df['38 User satisfaction cannot exist without trust'].value_counts()
# Out:
# Strongly agree (5)       122
# Agree (4)                117
# Strongly disagree (1)     18
# Dis-agree (2)              7
# indifferent (3)            5
# Name: 38 User satisfaction cannot exist without trust, dtype: int64

# %%
df['39 Offering a wide variety of listed product in several category'].value_counts().plot(kind='bar')
df['39 Offering a wide variety of listed product in several category'].value_counts()
# Out:
# Strongly agree (5)    111
# Agree (4)              94
# indifferent (3)        57
# Dis-agree (2)           7
# Name: 39 Offering a wide variety of listed product in several category, dtype: int64

# %%
df['40 Provision of complete and relevant product information'].value_counts().plot(kind='bar')
df['40 Provision of complete and relevant product information'].value_counts()
# Out:
# Strongly agree (5)    135
# Agree (4)              98
# indifferent (3)        31
# Disagree (2)            5
# Name: 40 Provision of complete and relevant product information, dtype: int64

# %%
df['41 Monetary savings'].value_counts().plot(kind='bar')
df['41 Monetary savings'].value_counts()
# Out:
# Strongly agree (5)    148
# Agree (4)              75
# Disagree (2)           31
# indifferent (3)        15
# Name: 41 Monetary savings, dtype: int64

# %%
df['42 The Convenience of patronizing the online retailer'].value_counts().plot(kind='bar')
df['42 The Convenience of patronizing the online retailer'].value_counts()
# Out:
# Agree (4)             138
# indifferent (3)        77
# Strongly agree (5)     54
# Name: 42 The Convenience of patronizing the online retailer, dtype: int64

# %%
df['43 Shopping on the website gives you the sense of adventure'].value_counts().plot(kind='bar')
df['43 Shopping on the website gives you the sense of adventure'].value_counts()
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: 43 Shopping on the website gives you the sense of adventure, dtype: int64

# %%
df['44 Shopping on your preferred e-tailer enhances your social status'].value_counts().plot(kind='bar')
df['44 Shopping on your preferred e-tailer enhances your social status'].value_counts()
# Out:
# indifferent (3)          100
# Agree (4)                 59
# Strongly agree (5)        48
# Strongly disagree (1)     33
# Dis-agree (2)             29
# Name: 44 Shopping on your preferred e-tailer enhances your social status, dtype: int64

# %%
df['45 You feel gratification shopping on your favorite e-tailer'].value_counts().plot(kind='bar')
df['45 You feel gratification shopping on your favorite e-tailer'].value_counts()
# Out:
# indifferent (3)          101
# Strongly agree (5)        65
# Agree (4)                 63
# Disagree (2)              22
# Strongly disagree (1)     18
# Name: 45 You feel gratification shopping on your favorite e-tailer, dtype: int64

# %%
df['46 Shopping on the website helps you fulfill certain roles'].value_counts().plot(kind='bar')
df['46 Shopping on the website helps you fulfill certain roles'].value_counts()
# Out:
# Agree (4)                88
# indifferent (3)          88
# Strongly agree (5)       38
# Strongly disagree (1)    33
# Dis-agree (2)            22
# Name: 46 Shopping on the website helps you fulfill certain roles, dtype: int64

# %%
df['47 Getting value for money spent'].value_counts().plot(kind='bar')
df['47 Getting value for money spent'].value_counts()
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: 47 Getting value for money spent, dtype: int64

# %%
df['47 Getting value for money spent'].value_counts().plot(kind='bar')
df['47 Getting value for money spent'].value_counts()
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: 47 Getting value for money spent, dtype: int64

# %%
plt.figure(figsize=(20,38))
c=1
for i in df.columns[65:72]:
    plt.subplot(5,2,c)
    c=c+1
    ax = sns.countplot(y = df[i],palette='Accent')
    plt.xticks(rotation=90)
    plt.xlabel(i)
    plt.ylabel('Category')
    
    total = len(df[i])
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))
    
        plt.tight_layout()

# %%
#Creating one Hot encode for Recommend online retailers

df['recommend_amazon'] = df['Which of the Indian online retailer would you recommend to a friend?'].apply(lambda x :1 if (x.lower().find('amazon.in') >=0) else 0  )

df['recommend_flipkart'] = df['Which of the Indian online retailer would you recommend to a friend?'].apply(lambda x :1 if (x.lower().find('flipkart') >=0) else 0  )

df['recommend_myntra'] = df['Which of the Indian online retailer would you recommend to a friend?'].apply(lambda x :1 if (x.lower().find('myntra') >=0) else 0  )

df['recommend_paytm'] = df['Which of the Indian online retailer would you recommend to a friend?'].apply(lambda x :1 if (x.lower().find('paytm') >=0) else 0  )

df['recommend_snapdeal'] = df['Which of the Indian online retailer would you recommend to a friend?'].apply(lambda x :1 if (x.lower().find('snapdeal') >=0) else 0 )

# %%
df[0:10]
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
# 5                Female         31-40 years
# 6                  Male         41-50 yaers
# 7                  Male         41-50 yaers
# 8                Female  Less than 20 years
# 9                Female         31-40 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
# 5                                 Noida
# 6                                 Delhi
# 7                                 Delhi
# 8                                 Solan
# 9                                 Delhi
#
# ...

# %%
plt.figure(figsize=(10,20))
c=1
for i in df.columns[71:]:
    plt.subplot(5,2,c)
    c=c+1
    ax = sns.countplot(y = df[i],palette='Set2')
    plt.xticks(rotation=90)
    plt.xlabel(i)
    plt.ylabel('Category')
    
    total = len(df[i])
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))
    
plt.tight_layout()

# %%
plt.figure(figsize=(40,30))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Amazon is recoomeded by 81.4% of of the customers.
#
# Snapdeal is recommended by 4.1% of the customers.
#
# Flipkart is recommed by 47.2 of the customers.
#
# Myntra is recommended by 28% of the customers.
#
# Paytm is recommeded by 16% of the customers
